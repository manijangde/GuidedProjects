# %% [markdown]
# # Best Markets For e-Learning
#
# Objective is to find best place to advertise e-leanring product that offer progamming courses. Thats mainly on mobile and web developments.

# %%
#importing python libs
import pandas as pd
import matplotlib.pyplot as plt

#load dataset:
fcc = pd.read_csv("2017-fCC-New-Coders-Survey-Data.csv")

#shape of dataset:
print(fcc.shape)

#print first 5 rows of dataset: 
fcc.head()
# Out:
# (18175, 136)
# c:\users\jangdm2\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (17,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN  between 100,000 and 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFCC  \
# 0                   NaN                   NaN  ...         NaN
# 1                   NaN                   NaN  ...         1.0
# 2                   NaN                   NaN  ...         NaN
# 3                   NaN                   NaN  ...         1.0
# 4                   NaN                   NaN  ...         NaN
#
#    YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               1.0
# 3                    1.0               NaN               NaN
# 4                    NaN               NaN               NaN
#
#    YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks YouTubeOther  \
# 0                 NaN         NaN                  NaN          NaN
# 1                 NaN         NaN                  NaN          NaN
# 2                 1.0         NaN                  NaN          NaN
# 3                 1.0         NaN                  NaN          NaN
# 4                 NaN         NaN                  NaN          NaN
#
#    YouTubeSimplilearn  YouTubeTheNewBoston
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
# [5 rows x 136 columns]

# %% [markdown]
# ## Lets check interests on various job role

# %%
# Unique counts for 'JobRoleInterest'
fcc['JobRoleInterest'].value_counts()
# Out:
# Full-Stack Web Developer                                                                                                                                                                                                                                 823
#   Front-End Web Developer                                                                                                                                                                                                                                450
#   Data Scientist                                                                                                                                                                                                                                         152
# Back-End Web Developer                                                                                                                                                                                                                                   142
#   Mobile Developer                                                                                                                                                                                                                                       117
# Game Developer                                                                                                                                                                                                                                           114
# Information Security                                                                                                                                                                                                                                      92
# Full-Stack Web Developer,   Front-End Web Developer                                                                                                                                                                                                       64
#   Front-End Web Developer, Full-Stack Web Developer                                                                                                                                                                                                       56
#   Product Manager                                                                                                                                                                                                                                         55
# Data Engineer                                                                                                                                                                                                                                             53
#   User Experience Designer                                                                                                                                                                                                                                52
#   User Experience Designer,   Front-End Web Developer                                                                                                                                                                                                     43
#   Front-End Web Developer, Back-End Web Developer, Full-Stack Web Developer                                                                                                                                                                               39
# Back-End Web Developer,   Front-End Web Developer, Full-Stack Web Developer                                                                                                                                                                               36
# Back-End Web Developer, Full-Stack Web Developer,   Front-End Web Developer                                                                                                                                                                               36
#   DevOps / SysAdmin                                                                                                                                                                                                                                       36
# Full-Stack Web Developer,   Front-End Web Developer, Back-End Web Developer                                                                                                                                                                               31
#   Front-End Web Developer, Full-Stack Web Developer, Back-End Web Developer                                                                                                                                                                               30
#   Front-End Web Developer,   User Experience Designer                                                                                                                                                                                                     29
# Full-Stack Web Developer,   Mobile Developer                                                                                                                                                                                                              29
# Back-End Web Developer, Full-Stack Web Developer                                                                                                                                                                                                          27
# Full-Stack Web Developer, Back-End Web Developer                                                                                                                                                                                                          26
# Back-End Web Developer,   Front-End Web Developer                                                                                                                                                                                                         20
# Full-Stack Web Developer, Back-End Web Developer,   Front-End Web Developer                                                                                                                                                                               19
# Data Engineer,   Data Scientist                                                                                                                                                                                                                           19
#   Front-End Web Developer,   Mobile Developer                                                                                                                                                                                                             18
# Full-Stack Web Developer,   Data Scientist                                                                                                                                                                                                                17
#   Mobile Developer, Game Developer                                                                                                                                                                                                                        16
#   Data Scientist, Data Engineer                                                                                                                                                                                                                           16
#                                                                                                                                                                                                                                                         ...
# Java developer                                                                                                                                                                                                                                             1
# Game Developer,   DevOps / SysAdmin,   Mobile Developer                                                                                                                                                                                                    1
#   DevOps / SysAdmin,   Front-End Web Developer, Back-End Web Developer, Information Security, Full-Stack Web Developer                                                                                                                                     1
#   Quality Assurance Engineer, Back-End Web Developer, Data Engineer, Game Developer,   Data Scientist, Full-Stack Web Developer,   Front-End Web Developer,   Mobile Developer,   User Experience Designer                                                 1
#   DevOps / SysAdmin, Game Developer,   Mobile Developer,   Data Scientist                                                                                                                                                                                  1
#   Mobile Developer, Full-Stack Web Developer,   User Experience Designer,   Front-End Web Developer, Back-End Web Developer, Information Security,   Product Manager                                                                                       1
# Full-Stack Web Developer, Back-End Web Developer, Data Engineer,   Quality Assurance Engineer,   Data Scientist                                                                                                                                            1
# Game Developer,   Front-End Web Developer, Full-Stack Web Developer,   Product Manager, Data Engineer                                                                                                                                                      1
#   Mobile Developer, Information Security,   Front-End Web Developer, Full-Stack Web Developer,   DevOps / SysAdmin,   User Experience Designer                                                                                                             1
# Game Developer, Information Security, Back-End Web Developer, Full-Stack Web Developer,   Mobile Developer,   Front-End Web Developer                                                                                                                      1
# Full-Stack Web Developer,   DevOps / SysAdmin, Back-End Web Developer,   Front-End Web Developer                                                                                                                                                           1
# Financial Services                                                                                                                                                                                                                                         1
#   Data Scientist, Full-Stack Web Developer, Information Security, Data Engineer, Back-End Web Developer                                                                                                                                                    1
# Information Security, Full-Stack Web Developer,   User Experience Designer,   Product Manager, Game Developer,   DevOps / SysAdmin,   Mobile Developer, Back-End Web Developer                                                                             1
#   User Experience Designer, Back-End Web Developer,   Mobile Developer, Game Developer,   Front-End Web Developer                                                                                                                                          1
# Data Engineer, Information Security, Full-Stack Web Developer,   Data Scientist,   Front-End Web Developer,   Quality Assurance Engineer, Back-End Web Developer                                                                                           1
#   Mobile Developer,   Product Manager, Full-Stack Web Developer, Back-End Web Developer,   Front-End Web Developer, Game Developer                                                                                                                         1
#   DevOps / SysAdmin, Full-Stack Web Developer,   Mobile Developer, Software Engineer                                                                                                                                                                       1
# Full-Stack Web Developer,   Mobile Developer,   Product Manager, Back-End Web Developer,   User Experience Designer,   Front-End Web Developer                                                                                                             1
# Full-Stack Web Developer, Back-End Web Developer, Game Developer,   Mobile Developer,   Front-End Web Developer                                                                                                                                            1
#   Mobile Developer,   Data Scientist, Data Engineer, Back-End Web Developer, Full-Stack Web Developer                                                                                                                                                      1
# Full-Stack Web Developer,   Mobile Developer,   Front-End Web Developer, Game Developer, Back-End Web Developer                                                                                                                                            1
#   Quality Assurance Engineer, Data Engineer,   DevOps / SysAdmin, Full-Stack Web Developer, Information Security,   Front-End Web Developer,   Mobile Developer, Game Developer, Back-End Web Developer,   User Experience Designer,   Data Scientist      1
# Full-Stack Web Developer,   Mobile Developer,   Data Scientist,   Front-End Web Developer                                                                                                                                                                  1
# Full-Stack Web Developer,   DevOps / SysAdmin,   Front-End Web Developer,   User Experience Designer,   Mobile Developer,   Quality Assurance Engineer                                                                                                     1
# Full-Stack Web Developer,   Front-End Web Developer,   User Experience Designer,   Data Scientist                                                                                                                                                          1
#   Product Manager, Full-Stack Web Developer,   Front-End Web Developer                                                                                                                                                                                     1
# Back-End Web Developer,   Front-End Web Developer,   DevOps / SysAdmin                                                                                                                                                                                     1
#   Front-End Web Developer,   Quality Assurance Engineer, Information Security,   User Experience Designer,   DevOps / SysAdmin, Full-Stack Web Developer, Data Engineer, Back-End Web Developer                                                            1
#   Mobile Developer, Back-End Web Developer,   User Experience Designer, Game Developer, Full-Stack Web Developer,   Front-End Web Developer                                                                                                                1
# Name: JobRoleInterest, Length: 3213, dtype: int64

# %% [markdown]
# majoroty are interested in web development!

# %% [markdown]
# ## Check for the location

# %%
#Keep only clear role: 
fcc_good = fcc[fcc['JobRoleInterest'].notnull()].copy()

#unique counts for locations: 
absolute_frequencies = fcc_good['CountryLive'].value_counts()
relative_frequencies = fcc_good['CountryLive'].value_counts(normalize = True) * 100

#Create new dataframe:
pd.DataFrame(data = {'Absolute frequency': absolute_frequencies, 
                     'Percentage': relative_frequencies}
            )
# Out:
#                                Absolute frequency  Percentage
# United States of America                     3125   45.700497
# India                                         528    7.721556
# United Kingdom                                315    4.606610
# Canada                                        260    3.802281
# Poland                                        131    1.915765
# Brazil                                        129    1.886517
# Germany                                       125    1.828020
# Australia                                     112    1.637906
# Russia                                        102    1.491664
# Ukraine                                        89    1.301550
# Nigeria                                        84    1.228429
# Spain                                          77    1.126060
# France                                         75    1.096812
# Romania                                        71    1.038315
# Netherlands (Holland, Europe)                  65    0.950570
# Italy                                          62    0.906698
# Serbia                                         52    0.760456
# Philippines                                    52    0.760456
# Greece                                         46    0.672711
# Ireland                                        43    0.628839
# South Africa                                   39    0.570342
# Mexico                                         37    0.541094
# Turkey                                         36    0.526470
# Singapore                                      34    0.497221
# Hungary                                        34    0.497221
# New Zealand                                    33    0.482597
# Argentina                                      32    0.467973
# Croatia                                        32    0.467973
# Sweden                                         31    0.453349
# Norway                                         31    0.453349
# ...                                           ...         ...
# Qatar                                           1    0.014624
# Sudan                                           1    0.014624
# Yemen                                           1    0.014624
# Kyrgyzstan                                      1    0.014624
# Mozambique                                      1    0.014624
# Jordan                                          1    0.014624
# Samoa                                           1    0.014624
# Guatemala                                       1    0.014624
# Guadeloupe                                      1    0.014624
# Angola                                          1    0.014624
# Nicaragua                                       1    0.014624
# Panama                                          1    0.014624
# Botswana                                        1    0.014624
# Somalia                                         1    0.014624
# Vanuatu                                         1    0.014624
# Cayman Islands                                  1    0.014624
# Nambia                                          1    0.014624
# Channel Islands                                 1    0.014624
# Rwanda                                          1    0.014624
# Gibraltar                                       1    0.014624
# Bolivia                                         1    0.014624
# Aruba                                           1    0.014624
# Turkmenistan                                    1    0.014624
# Cameroon                                        1    0.014624
# Trinidad & Tobago                               1    0.014624
# Papua New Guinea                                1    0.014624
# Liberia                                         1    0.014624
# Gambia                                          1    0.014624
# Cuba                                            1    0.014624
# Myanmar                                         1    0.014624
#
# [137 rows x 2 columns]

# %% [markdown]
# It shows USA, India and UK are top 3 locations!

# %% [markdown]
# ## Check for spending

# %%
#replace 0s with 1s to avoid division by 0 error:
fcc_good['MonthsProgramming'].replace(0,1, inplace = True)

#create new column:
fcc_good['money_per_month'] = fcc_good['MoneyForLearning'] / fcc_good['MonthsProgramming']
fcc_good['money_per_month'].isnull().sum()
# Out:
# 675

# %%
#non-null values only:
fcc_good = fcc_good[fcc_good['money_per_month'].notnull()]

# %%
#remove null values:
fcc_good = fcc_good[fcc_good['CountryLive'].notnull()]

#unique counts:
fcc_good['CountryLive'].value_counts().head()
# Out:
# United States of America    2933
# India                        463
# United Kingdom               279
# Canada                       240
# Poland                       122
# Name: CountryLive, dtype: int64

# %%
#finding mean:
countries_mean = fcc_good.groupby('CountryLive').mean()
countries_mean['money_per_month'][['United States of America',
                            'India', 'United Kingdom',
                            'Canada']]
# Out:
# CountryLive
# United States of America    227.997996
# India                       135.100982
# United Kingdom               45.534443
# Canada                      113.510961
# Name: money_per_month, dtype: float64

# %% [markdown]
# # Check for the outliers

# %%
#keep only 3 countries:
only_4 = fcc_good[fcc_good['CountryLive'].str.contains(
    'United States of America|India|United Kingdom|Canada')]

# Box plots:
import seaborn as sns

sns.boxplot(y = 'money_per_month', x = 'CountryLive',
            data = only_4)
plt.title('Money Spent Per Month Per Country\n(Distributions)',
         fontsize = 16)
plt.ylabel('Money per month (US dollars)')
plt.xlabel('Country')
plt.xticks(range(4), ['US', 'UK', 'India', 'Canada'])
plt.show()

# %%
#less than 20000 per month
fcc_good = fcc_good[fcc_good['money_per_month'] < 20000]

# %%
#re-calculate mean:
countries_mean = fcc_good.groupby('CountryLive').mean()
countries_mean['money_per_month'][['United States of America',
                            'India', 'United Kingdom',
                            'Canada']]
# Out:
# CountryLive
# United States of America    183.800110
# India                       135.100982
# United Kingdom               45.534443
# Canada                      113.510961
# Name: money_per_month, dtype: float64

# %%
#keep interested countries:
only_4 = fcc_good[fcc_good['CountryLive'].str.contains(
    'United States of America|India|United Kingdom|Canada')]

# Box plots;
sns.boxplot(y = 'money_per_month', x = 'CountryLive',
            data = only_4)
plt.title('Money Spent Per Month Per Country\n(Distributions)',
         fontsize = 16)
plt.ylabel('Money per month (US dollars)')
plt.xlabel('Country')
plt.xticks(range(4), ['US', 'UK', 'India', 'Canada']) # avoids tick labels overlap
plt.show()

# %%
#extreme outliers for India
india_outliers = only_4[
    (only_4['CountryLive'] == 'India') & 
    (only_4['money_per_month'] >= 2500)]
india_outliers
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1728   24.0               0.0             NaN                NaN          NaN
# 1755   20.0               0.0             NaN                NaN          NaN
# 7989   28.0               0.0             NaN                NaN          NaN
# 8126   22.0               0.0             NaN                NaN          NaN
# 13398  19.0               0.0             NaN                NaN          NaN
# 15587  27.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1728                 NaN             NaN  between 100,000 and 1 million
# 1755                 NaN             NaN            more than 1 million
# 7989                 NaN             NaN  between 100,000 and 1 million
# 8126                 NaN             NaN            more than 1 million
# 13398                NaN             NaN            more than 1 million
# 15587                NaN             NaN            more than 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFunFunFunction  \
# 1728                    NaN                   NaN  ...                    NaN
# 1755                    NaN                   NaN  ...                    NaN
# 7989                    1.0                   NaN  ...                    NaN
# 8126                    NaN                   NaN  ...                    NaN
# 13398                   NaN                   NaN  ...                    NaN
# 15587                   NaN                   NaN  ...                    NaN
#
#        YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 1728                NaN               NaN                 NaN         NaN
# 1755                NaN               1.0                 NaN         1.0
# 7989                NaN               NaN                 NaN         NaN
# 8126                1.0               NaN                 NaN         1.0
# 13398               NaN               NaN                 NaN         NaN
# 15587               1.0               1.0                 NaN         1.0
#
#        YouTubeMozillaHacks  YouTubeOther YouTubeSimplilearn  \
# 1728                   NaN           NaN                NaN
# 1755                   NaN           NaN                NaN
# 7989                   NaN           NaN                NaN
# 8126                   NaN           NaN                NaN
# 13398                  NaN           NaN                NaN
# 15587                  NaN           NaN                NaN
#
#        YouTubeTheNewBoston  money_per_month
# 1728                   NaN      5000.000000
# 1755                   NaN      3333.333333
# 7989                   NaN      5000.000000
# 8126                   1.0      5000.000000
# 13398                  NaN     10000.000000
# 15587                  NaN      4166.666667
#
# [6 rows x 137 columns]

# %%
# Remove the outliers for India
only_4 = only_4.drop(india_outliers.index)

# %%
#outliers for the US
us_outliers = only_4[
    (only_4['CountryLive'] == 'United States of America') & 
    (only_4['money_per_month'] >= 6000)]

us_outliers
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# 718    26.0               1.0             0.0                0.0
# 1222   32.0               1.0             0.0                0.0
# 3184   34.0               1.0             1.0                0.0
# 3930   31.0               0.0             NaN                NaN
# 6805   46.0               1.0             1.0                1.0
# 7198   32.0               0.0             NaN                NaN
# 7505   26.0               1.0             0.0                1.0
# 9778   33.0               1.0             0.0                1.0
# 16650  29.0               0.0             NaN                NaN
# 16997  27.0               0.0             NaN                NaN
# 17231  50.0               0.0             NaN                NaN
#
#                                  BootcampName  BootcampRecommend  \
# 718    The Coding Boot Camp at UCLA Extension                1.0
# 1222                            The Iron Yard                1.0
# 3184                           We Can Code IT                1.0
# 3930                                      NaN                NaN
# 6805                                 Sabio.la                0.0
# 7198                                      NaN                NaN
# 7505                                   Codeup                0.0
# 9778                             Grand Circus                1.0
# 16650                                     NaN                NaN
# 16997                                     NaN                NaN
# 17231                                     NaN                NaN
#
#        ChildrenNumber                 CityPopulation  CodeEventConferences  \
# 718               NaN            more than 1 million                   1.0
# 1222              NaN  between 100,000 and 1 million                   NaN
# 3184              NaN            more than 1 million                   NaN
# 3930              NaN  between 100,000 and 1 million                   NaN
# 6805              NaN  between 100,000 and 1 million                   NaN
# 7198              NaN            more than 1 million                   1.0
# 7505              NaN            more than 1 million                   NaN
# 9778              NaN  between 100,000 and 1 million                   NaN
# 16650             2.0            more than 1 million                   NaN
# 16997             1.0            more than 1 million                   NaN
# 17231             2.0              less than 100,000                   NaN
#
#        CodeEventDjangoGirls  ...  YouTubeFunFunFunction  YouTubeGoogleDev  \
# 718                     NaN  ...                    NaN               NaN
# 1222                    NaN  ...                    NaN               NaN
# 3184                    NaN  ...                    NaN               NaN
# 3930                    NaN  ...                    1.0               1.0
# 6805                    NaN  ...                    NaN               NaN
# 7198                    NaN  ...                    NaN               1.0
# 7505                    NaN  ...                    NaN               NaN
# 9778                    NaN  ...                    NaN               NaN
# 16650                   NaN  ...                    NaN               NaN
# 16997                   NaN  ...                    NaN               NaN
# 17231                   NaN  ...                    NaN               NaN
#
#        YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks  \
# 718                 NaN                 NaN         NaN                  NaN
# 1222                1.0                 NaN         NaN                  NaN
# 3184                NaN                 NaN         NaN                  NaN
# 3930                1.0                 1.0         1.0                  NaN
# 6805                NaN                 NaN         NaN                  NaN
# 7198                1.0                 1.0         NaN                  NaN
# 7505                NaN                 NaN         1.0                  NaN
# 9778                NaN                 NaN         NaN                  NaN
# 16650               NaN                 NaN         NaN                  NaN
# 16997               NaN                 NaN         NaN                  NaN
# 17231               NaN                 NaN         NaN                  NaN
#
#                      YouTubeOther YouTubeSimplilearn  YouTubeTheNewBoston  \
# 718                           NaN                NaN                  NaN
# 1222                          NaN                NaN                  NaN
# 3184                          NaN                NaN                  NaN
# 3930   various conf presentations                NaN                  NaN
# 6805                          NaN                NaN                  NaN
# 7198                          NaN                NaN                  NaN
# 7505                          NaN                NaN                  NaN
# 9778                          NaN                NaN                  NaN
# 16650                         NaN                NaN                  1.0
# 16997                         NaN                NaN                  NaN
# 17231                         NaN                NaN                  NaN
#
#        money_per_month
# 718        8000.000000
# 1222       6500.000000
# 3184       9000.000000
# 3930      10833.333333
# 6805      15000.000000
# 7198      14000.000000
# 7505       6666.666667
# 9778       8000.000000
# 16650     16666.666667
# 16997     12500.000000
# 17231     15000.000000
#
# [11 rows x 137 columns]

# %% [markdown]
# Find who did not respond to bootcam and programming less than 3 months

# %%
#didn't attendent a bootcamp
no_bootcamp = only_4[
    (only_4['CountryLive'] == 'United States of America') & 
    (only_4['money_per_month'] >= 6000) &
    (only_4['AttendedBootcamp'] == 0)
]

only_4 = only_4.drop(no_bootcamp.index)


#programming for less than 3 months
less_than_3_months = only_4[
    (only_4['CountryLive'] == 'United States of America') & 
    (only_4['money_per_month'] >= 6000) &
    (only_4['MonthsProgramming'] <= 3)
]

only_4 = only_4.drop(less_than_3_months.index)

# %%
#outliers for Canada
canada_outliers = only_4[
    (only_4['CountryLive'] == 'Canada') & 
    (only_4['money_per_month'] > 4500)]

canada_outliers
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 13659  24.0               1.0             0.0                0.0      Bloc.io
#
#        BootcampRecommend  ChildrenNumber       CityPopulation  \
# 13659                1.0             NaN  more than 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFunFunFunction  \
# 13659                   1.0                   NaN  ...                    NaN
#
#        YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 13659               NaN               NaN                 NaN         1.0
#
#        YouTubeMozillaHacks  YouTubeOther YouTubeSimplilearn  \
# 13659                  NaN           NaN                NaN
#
#        YouTubeTheNewBoston  money_per_month
# 13659                  NaN           5000.0
#
# [1 rows x 137 columns]

# %%
#outliers for Canada
only_4 = only_4.drop(canada_outliers.index)

# %%
#mean sum:
only_4.groupby('CountryLive').mean()['money_per_month']
# Out:
# CountryLive
# Canada                       93.065400
# India                        65.758763
# United Kingdom               45.534443
# United States of America    142.654608
# Name: money_per_month, dtype: float64

# %%
# Visualize the distributions:
sns.boxplot(y = 'money_per_month', x = 'CountryLive',
            data = only_4)
plt.title('Money Spent Per Month Per Country\n(Distributions)',
          fontsize = 16)
plt.ylabel('Money per month (US dollars)')
plt.xlabel('Country')
plt.xticks(range(4), ['US', 'UK', 'India', 'Canada']) # avoids tick labels overlap
plt.show()

# %%
#value counts:
only_4['CountryLive'].value_counts(normalize = True) * 100
# Out:
# United States of America    74.967908
# India                       11.732991
# United Kingdom               7.163030
# Canada                       6.136072
# Name: CountryLive, dtype: float64

# %% [markdown]
# Looks USA is best among all location to advertise course! rest is not so clear.
